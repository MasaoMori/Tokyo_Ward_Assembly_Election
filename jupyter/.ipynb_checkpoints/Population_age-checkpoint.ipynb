# %%
import pandas as pd
import glob as gb
import os

files = gb.glob('./data/Ward_Age/*')
dataname = '町丁目名年齢年代別人口分布'

d=os.getcwd()
prefix = d + '/data/Ward_Age/'

# %% [markdown]
# ## 大田区

# %%
ohta_file = prefix + '大田区2022年1月_rev.xlsx'

ohta_data = pd.read_excel(ohta_file).set_index('年齢')

ohta_finedata = pd.DataFrame(ohta_data.stack()).reset_index().set_axis(['年齢','町丁目名','人口'],axis=1)

ohta_finedata = ohta_finedata[['町丁目名','年齢','人口']]

ohta_finedata['町丁目名'] = ohta_finedata['町丁目名'].str.replace('　','')

ohta_finedata.to_excel(prefix + dataname + '（大田）.xlsx', index=False)

# %%
ohta_finedata.columns
# Out:
# Index(['町丁目名', '年齢', '人口'], dtype='object')

# %% [markdown]
# ### 品川

# %%
male=list(range(0,241,2))
female=list(range(1,241,2))

shina_file = prefix + '品川区2023年1月_rev.xls'
shina_data = pd.read_excel(shina_file, dtype={'行政コード':int})

shina_m = shina_data.loc[:,['行政コード','丁目名']+male].set_index(['行政コード','丁目名']).stack()
shina_f = shina_data.loc[:,['行政コード','丁目名']+female].set_index(['行政コード','丁目名']).stack()

shina_m_fine= pd.DataFrame(shina_m).reset_index().rename(columns={'level_2':'age',0:'人口'})
shina_m_fine['年齢']=shina_m_fine['age']//2

shina_f_fine= pd.DataFrame(shina_f).reset_index().rename(columns={'level_2':'age',0:'人口'})
shina_f_fine['年齢']=(shina_f_fine['age'])//2

scols=['行政コード','丁目名','年齢','人口']
mer=['行政コード','丁目名','年齢']

shina_m_fine=shina_m_fine.drop(columns=['age'])[scols]
shina_f_fine=shina_f_fine.drop(columns=['age'])[scols]

shina_finedata = pd.merge(shina_m_fine, shina_f_fine, on=mer)

shina_finedata['人口'] = shina_finedata['人口_x']+shina_finedata['人口_y']
shina_finedata = shina_finedata.drop(columns=['人口_x','人口_y']).reset_index(drop=True)
shina_finedata = shina_finedata.rename(columns={'丁目名':'町丁目名'})
shina_finedata.to_excel(prefix + dataname + '（品川）.xlsx', index=False)

# %%
shina_finedata.columns
# Out:
# Index(['行政コード', '町丁目名', '年齢', '人口'], dtype='object')

# %% [markdown]
# ### 目黒

# %%
meg_file = prefix +'目黒区2022年12月_rev.xlsx'
meg_data = pd.read_excel(meg_file)
#meg_data

top = meg_data[meg_data['a']=='町丁別年齢別人口表'].reset_index()['index']
end = meg_data[meg_data['a']=='104以上'].reset_index()['index']
#print(list(top))
#print(list(end))

meg_tmp = pd.DataFrame()

#meg_data['町丁目名']=''

for k in top:
    chomei = meg_data.iloc[k+1,0].replace('　','')

    for j in list(range(k+4,k+129)):
        meg_data.loc[j,'町丁目名'] = chomei

    chodf = meg_data.iloc[(k+4):(k+129),:]
    
    chodf = chodf[~(chodf['a'].str.contains('～',na=False))]
    chodf = chodf[~(chodf['a'].str.contains('以上',na=False))]
    
    chodf = chodf.rename(columns={'a':'年齢', 'b':'人口'})
    chodf['年齢'] = chodf['年齢'].astype(int)
    
    meg_tmp = pd.concat([meg_tmp, chodf])

meg_finedata = meg_tmp[['町丁目名','年齢','人口']]

meg_finedata.to_excel(prefix + dataname + '（目黒）.xlsx', index=False)

# %% [markdown]
# ### 港区

# %%
import tabula

mina_file = prefix + '港区2022年4月.pdf'

mina_data = tabula.read_pdf(mina_file,pages="1-117",stream=True)

# %% [raw]
# from pdfminer.pdfinterp import PDFResourceManager
# from pdfminer.converter import TextConverter
# from pdfminer.pdfinterp import PDFPageInterpreter
# from pdfminer.pdfpage import PDFPage
# from pdfminer.layout import LAParams
# from io import StringIO
#
# pdf_file_path = mina_file
#
# result = []
#
# with open(pdf_file_path , "rb") as pdf_file: #ファイルオブジェクトを受け取り、変数「pdf_file」に代入。
#     output = StringIO() #コンソールに出力されたテキストを取得するため、IOクラス「StringIO」使用
#     resource_manager = PDFResourceManager()
#     laparams = LAParams() #レイアウトの変更がなければデフォルトのままで
#     text_converter = TextConverter(resource_manager, output, laparams=laparams)
#     page_interpreter = PDFPageInterpreter(resource_manager, text_converter)
#
#     for i_page in PDFPage.get_pages(pdf_file): #1ベージずづ処理
#         page_interpreter.process_page(i_page)
#
#
#     output_text = output.getvalue()
#     result.append(output_text.split('\n')[2])
#     output.close()
#     text_converter.close()
#
# #print(output_text)
#
# l=output_text.split('\n')
#
# text = open(prefix + '港区町丁目名.txt',"w")
# text.write(output_text)
# text.close()

# %%
textfile = open(prefix+'港区町丁目名.txt','r')
output_text = textfile.read()
textfile.close()

import re

pattern = '(.+丁目)|(麻布.+町)|(麻布狸穴町)$'

minacho = re.findall(pattern, output_text)

from itertools import chain
def flatten(nested_list):
    return list(chain.from_iterable(nested_list))

#flatten(list(map(lambda x: list(x), minacho)))

chomeilist = list(map((lambda y: ''.join(y)), list(map(lambda x: list(x), minacho))))

# %%
mina_finedata = pd.DataFrame()

for i in range(0,116):
    if i != 39:
        k = mina_data[i].iloc[:21,0:3].set_axis(['世代','a','b'],axis=1)
        k['町丁目名'] = chomeilist[i]
        k = k.fillna(0)
        k = k.astype({'a':str, 'b':str})
        k['a'] = k['a'].str.replace(',','')
        k['a'] = k['a'].str.replace(r'0\.0','0', regex=True)
        k['b'] = k['b'].str.replace(',','')
        k['b'] = k['b'].str.replace(r'0\.0','0', regex=True)
    else:
        k = mina_data[i].iloc[:,0:2].set_axis(['世代','a'],axis=1)
        k['町丁目名'] = chomeilist[i]
        k['a'] = k['a'].str.replace(',','')
        k['a'] = k['a'].str.replace(r'0\.0','0', regex=True)        
        k['b'] = '0'
        
    mina_finedata = pd.concat([mina_finedata, k])

mina_finedata = mina_finedata.astype({'a':int, 'b':int}).reset_index(drop=True) 

mina_finedata['人口'] = mina_finedata['a'] + mina_finedata['b']
#

for r in mina_finedata.itertuples():
    if not(((r.a == 0) and (r.b==r.人口)) or ((r.b==0) and (r.a==r.人口))):
        print(r.町丁目名, ' ', r.a, r.b)


mina_finedata = mina_finedata.drop(columns=['a','b'])[['町丁目名','世代','人口']]
mina_finedata.to_excel(prefix + dataname + '（港）.xlsx', index=False)

# %% [markdown]
# ### 渋谷

# %%
shib_data = pd.read_excel(prefix + '渋谷区2022年1月.xls', header=1)

shib_finedata = shib_data[['町丁名','年齢','人口']]

shib_finedata.to_excel(prefix + dataname + '（渋谷）.xlsx', index=False)

# %% [markdown]
# ### 台東

# %%
import pandas as pd
tai_data = pd.read_excel(prefix + '台東区2023年1月.xlsx', header=57)

# %%
tai_data #.iloc[2,3].split('\n')628

import numpy as np
#tai_tmp = pd.DataFrame([],index=list(range(0,627)), columns=list(range(0,14)))

tai_tmp = []

for r,s in tai_data.iterrows():
    if (s[0] == s[0]) and len(s[0].split('\n')) > 1:
        lt = s[0].split('\n')
        print(lt)
        l = [lt[1],''.join(lt[2:])]
    else:
        l = ['']
    
    for i in range(2,14):
        k = str(s[i]).split('\n')
        if len(k) > 2:
            l.append(k[-2])
        else:
            l.append('')

    if not len(''.join(l)) == 0:
        tai_tmp.append(l)
# Out:
# ['行政区', '000111', '台東1丁目']
# ['行政区', '000112', '台東2丁目']
# ['行政区', '000113', '台東3丁目']
# ['行政区', '000114', '台東4T', '昌']
# ['丁', '区1・；', '政12象', '柾m橋', '行00畔―', 'IQ0柳目']
# ['行政区', '000122', '柳橋2T', '目']
# ['行政区', '000131', '浅草橋1', '丁目']
# ['行政区', '000132', '浅草橋2', '丁目']
# ['行政区', '000133', '浅草橋3', '丁目']
# ['区4か', '拒34橋政13封1', '行00駐4', '千00浅T']
# ['行政選', '000135', '浅草橋5', '丁目']
# ['行政区', '000141', '鳥越iT 国']
# ['行政区', '000142', '鳥越2丁', '目']
# ['行政区', '000151', '蔵前1丁', '目']
# ['行政区', '000152', '蔵前2丁', '目']
# ['3', '什え一D--', '1II', 'T0ュロn', '0', '0', 'Jー』曲国IFFE王FFFFE']
# ['行政区', '000154', '蔵前4丁目']
# ['行政区', '000161', '小島1丁目']
# ['行政区', '000162', '小島2丁目']
# ['行政区', '000171', '三筋1丁目']
# ['行政区', '000172', '三筋2丁', '目']
# ['行政区', '000180', '秋葉原']
# ['行政区', '000191', '上野I丁', '目']
# ['行政区', '000192', '上野2丁', '目']
# ['半昭3', '白えgdt', '正い一11プャ」', '】丁一n憂ュ', '2イJ一n11コ44', 'nリコt工十', '1山国曲曲1曲山山山山国1山曲山国1山山国111山山山1山1国山1ョョョョョョョョョョョIllLI国国11にILI肥1叫L王王王11臣11叫曲王王王臣1王王王王王王王王王王1王王王王王1王臣王王ー■']
# ['行政区', '000194', '上野4丁', '目']
# ['行政選', '000195', '上野ST', '目']
# ['行政区', '000196', '上野6丁', '鳳']
# ['丁', '区7り', '政9', '証Ql野', '行0導1', '千00']
# ['枢吐野', '徴00020「朔']
# ['行政区', '000202', '東上野2', '丁目']
# ['行政区', '000203', '東上野3', '丁目']
# ['行政区', '000204', '東上野4', '丁目']
# ['行政区', '000205', '東上野5', '丁目']
# ['区6白', '拒妬野', '政20雄1', '行00一し斗', '100東丁']
# ['行政区', '000211', '元浅草1', '丁目']
# ['行政区', '000212', '元浅草2', '丁胃']
# ['行政区', '000213', '元浅草3', '丁目']
# ['行政区', '000214', '元浅草4 T目']
# ['ヒE畔11一', '正芭n乙IL', '」1いnl一】丁一n', '211nU一一干', '一nョメ', '国国」国』国国』国』国国」国」国』国国国』国国』国国国1』国国国国』国」国』国国国』国国国国』国国国国国国国国国国国国国1山国国国国コ国']
# ['行政区', '000222', '寿2T目']
# ['行政区', '000223', '寿3丁目']
# ['行政区', '000224', '寿4丁目']
# ['行政区', '000231', '駒形1丁目']
# ['1・L丁', '区2ジ', '政23引', '誕02形', '行00酬―', '子00駒目']
# ['行政区', '000241', '北上野1', '丁目']
# ['行政区', '000242', '北上野2', '丁目']
# ['行政区', '000251', '下谷1丁', '目']
# ['行政区', '000252', '下谷2丁', '目']
# ['土渇3 」く一Di-', '記是n乙gJ', '一丁nUノ41', 'Jァ1一n一1、コJ4', '一n】1ILLI十']

# %%
tai_tmp
# Out:
# [['000111',
#   '台東1丁目',
#   '60',
#   '31',
#   '57',
#   '59',
#   '113',
#   '215',
#   '251',
#   '233',
#   '203',
#   '(4)173',
#   '(4)112',
#   '128'],
#  ['',
#   '92',
#   '77',
#   '(1) 76',
#   '75',
#   '67',
#   '51',
#   '20',
#   '5',
#   '1',
#   '0',
#   '(0)0',
#   '(72)'],
#  ['000112',
#   '台東2丁目',
#   '82',
#   '66',
#   '43',
#   '51',
#   '163',
#   '289',
#   '306',
#   '250',
#   '198',
#   '192',
#   '174',
#   '135'],
#  ['', '79', '68', '98', '90', '67', '31', '23', '12', '2', '0', '(0)0', '一'],
#  ['000113',
#   '台東3丁目',
#   '96',
#   '66',
#   '50',
#   '83',
#   '164',
#   '274',
#   '324',
#   '263',
#   '288',
#   '274',
#   '218',
#   '5'],
#  ['',
#   '133',
#   '126',
#   '123',
#   '119',
#   '97',
#   '69',
#   '38',
#   '10',
#   '0',
#   '0',
#   '(0)0',
#   '一'],
#  ['000114',
#   '台東4T昌',
#   '37',
#   '34',
#   '38',
#   '47',
#   '62',
#   '77',
#   '(2の87',
#   '153',
#   '163',
#   '138',
#   '120',
#   '亡り一'],
#  ['', '42', '(1)60', '89', '74', '53', '22', '15', '6', '0', '0', '(0)0', ''],
#  ['区1・；',
#   '政12象柾m橋行00畔―IQ0柳目',
#   '29',
#   '25',
#   '30',
#   '30',
#   '87',
#   '167',
#   '149',
#   '115',
#   '116',
#   '113',
#   '123',
#   '一D一'],
#  ['',
#   '(1) 67',
#   '52',
#   '62',
#   '34',
#   '57',
#   '（の20',
#   '16',
#   '2',
#   '1',
#   '0',
#   '(0)0',
#   ''],
#  ['000122',
#   '柳橋2T目',
#   '93',
#   '65',
#   '37',
#   '(5) 49',
#   '111',
#   '(18)201',
#   '359',
#   '258',
#   '204',
#   '192',
#   '78',
#   ''],
#  ['', '65', '37', '41', '34', '26', '24', '15', '3', '2', '0', '(0)0', ''],
#  ['000131',
#   '浅草橋1丁目',
#   '23',
#   '21',
#   '24',
#   '27',
#   '75',
#   '181',
#   '158',
#   '133',
#   '109',
#   '97',
#   '75',
#   ''],
#  ['', '53', '49', '(1) 52', '53', '39', '41', '10', '4', '1', '0', '(0)0', ''],
#  ['000132',
#   '浅草橋2丁目',
#   '49',
#   '45',
#   '40',
#   '70',
#   '125',
#   '190',
#   '64',
#   '167',
#   '124',
#   '134',
#   '107',
#   '79'],
#  ['',
#   '80',
#   '57',
#   '90',
#   '79',
#   '61',
#   '(1) 50',
#   '26',
#   '7',
#   '0',
#   '0',
#   '(0)0',
#   '1, 736'],
#  ['000133',
#   '浅草橋3丁目',
#   '71',
#   '59',
#   '58',
#   '53',
#   '106',
#   '252',
#   '209',
#   '224',
#   '196',
#   '85',
#   '173',
#   '108'],
#  ['',
#   '82',
#   '74',
#   '70',
#   '71',
#   '61',
#   '34',
#   '20',
#   '5',
#   '0',
#   '0',
#   '(0)0',
#   '2,106'],
#  ['拒34橋政13封1',
#   '行00駐4千00浅T',
#   '14',
#   '34',
#   'l6',
#   '27',
#   '59',
#   '119',
#   '95',
#   '(1)66',
#   '70',
#   '83',
#   '(4) 71',
#   '47'],
#  ['', '22', '13', '29', '23', '19', '15', '8', '3', 'l', '0', '(0)0', '834'],
#  ['000135',
#   '浅草橋5丁目',
#   '92',
#   '70',
#   '46',
#   '36',
#   '88',
#   '283',
#   '294',
#   '248',
#   '230',
#   '198',
#   '(4)167',
#   '97'],
#  ['',
#   '91',
#   '88',
#   '80',
#   '78',
#   '52',
#   '39',
#   '14',
#   '?',
#   'I',
#   '0',
#   '(0)0',
#   '2,299'],
#  ['000141',
#   '鳥越iT 国',
#   '68',
#   '64',
#   '55',
#   '47',
#   '109',
#   '160',
#   '151',
#   '174',
#   '169',
#   '160',
#   '155',
#   '80'],
#  ['',
#   '(2) 55',
#   '(2) 56',
#   '77',
#   '82',
#   '(0)46',
#   '56',
#   '21',
#   '4',
#   '0',
#   '0',
#   '0',
#   '1, 807'],
#  ['000142',
#   '鳥越2丁目',
#   '38',
#   '43',
#   '25',
#   '26',
#   '95',
#   '171',
#   '155',
#   '138',
#   '(13)47',
#   '134',
#   '113',
#   '81'],
#  ['', '62', '39', '47', '53', '33', '19', '9', '4', '1', '0', '0', '1, 400'],
#  ['000151',
#   '蔵前1丁目',
#   '45',
#   '15',
#   '(1)9',
#   '14',
#   '52',
#   '202',
#   '156',
#   '(1)121',
#   '85',
#   '73',
#   '(1)23',
#   '41'],
#  ['',
#   '(1) 24',
#   '19',
#   '15',
#   '1O',
#   '13',
#   '9',
#   '3',
#   '1',
#   '0',
#   '0',
#   '(0)0',
#   '955'],
#  ['000152',
#   '蔵前2丁目',
#   '95',
#   '(1) 85',
#   '50',
#   '38',
#   '51',
#   '208',
#   '228',
#   '217',
#   '205',
#   '191',
#   '181',
#   '89'],
#  ['',
#   '81',
#   '(2) 53',
#   '60',
#   '37',
#   '32',
#   '20',
#   '17',
#   '(0)4',
#   '(0)4',
#   '0',
#   '0',
#   ''],
#  ['什え一D--',
#   '1IIT0ュロn00Jー』曲国IFFE王FFFFE',
#   '50',
#   '50',
#   '39',
#   '21',
#   '57',
#   '139',
#   '152',
#   '119',
#   '141',
#   '128',
#   '126',
#   '(2) 71'],
#  ['',
#   '51',
#   '33',
#   '(1) 75',
#   '44',
#   '38',
#   '22',
#   '8',
#   'I',
#   '1',
#   '0',
#   '(0)0',
#   '1,366'],
#  ['000154',
#   '蔵前4丁目',
#   '142',
#   '144',
#   '93',
#   '(1)66',
#   '122',
#   '(14)343',
#   '390',
#   '182',
#   '333',
#   '342',
#   '(8)150',
#   '一り一'],
#  ['',
#   '(1) 86',
#   '87',
#   '89',
#   '83',
#   '75',
#   '59',
#   '26',
#   '10',
#   '1',
#   '0',
#   '(0)0',
#   '一'],
#  ['000161',
#   '小島1丁目',
#   '48',
#   '56',
#   '(1)38',
#   '51',
#   '87',
#   '(is)217',
#   '185',
#   '(ii)166',
#   '160',
#   '154',
#   '79',
#   '5'],
#  ['', '85', '56', '69', '60', '54', '40', '17', '5', '1', '0', '(0)0', '合・1,'],
#  ['000162',
#   '小島2丁目',
#   '39',
#   '37',
#   '33',
#   '35',
#   '67',
#   '166',
#   '158',
#   '145',
#   '101',
#   '(7) 134',
#   '139',
#   '一hU一'],
#  ['',
#   '90',
#   '65',
#   '64',
#   '56',
#   '(1) 62',
#   '47',
#   '16',
#   '4',
#   'l',
#   '0',
#   '(0)0',
#   '一'],
#  ['000171',
#   '三筋1丁目',
#   '78',
#   '99',
#   '62',
#   '65',
#   '117',
#   '(16)148',
#   '(2の286',
#   '248',
#   '222',
#   '(9) 214',
#   '207',
#   '二U一'],
#  ['', '(3) 113', '87', '90', '77', '72', '46', '14', '7', '', '0', '', ''],
#  ['000172',
#   '三筋2丁目',
#   '81',
#   '59',
#   '63',
#   '59',
#   '90',
#   '(20)104',
#   '207',
#   '213',
#   '181',
#   '178',
#   '89',
#   '119'],
#  ['',
#   '96',
#   '(3) 80',
#   '99',
#   '78',
#   '61',
#   '42',
#   '24',
#   '3',
#   '1',
#   '0',
#   '(0)0',
#   '2,120'],
#  ['000180',
#   '秋葉原',
#   '2',
#   '(0)0',
#   '0',
#   '(0)0',
#   '18',
#   '17',
#   '7',
#   '4',
#   '2',
#   '(a)0',
#   '3',
#   '4'],
#  ['',
#   '(0)0',
#   '(0)2',
#   '3',
#   '(a)a',
#   '0',
#   '1',
#   '1',
#   '(0)0',
#   '0',
#   '0',
#   '(0)0',
#   '68'],
#  ['000191',
#   '上野I丁目',
#   '10',
#   '22',
#   '18',
#   '15',
#   '31',
#   '35',
#   '47',
#   '46',
#   '48',
#   '65',
#   '49',
#   '43'],
#  ['',
#   '45',
#   'ニJ一',
#   '(0)43',
#   '30',
#   '22',
#   '17',
#   '5',
#   '4',
#   '1',
#   '0',
#   '(0)0',
#   '638'],
#  ['000192',
#   '上野2丁目',
#   '1',
#   '3',
#   '1',
#   '6',
#   '9',
#   '3',
#   '8',
#   '5',
#   '14',
#   '17',
#   '19',
#   '13'],
#  ['', '5', '一」U一', '6', '1O', '5', '2', '0', '1', '0', '0', '0', '138'],
#  ['白えgdt',
#   '正い一11プャ」】丁一n憂ュ2イJ一n11コ44nリコt工十1山国曲曲1曲山山山山国1山曲山国1山山国111山山山1山1国山1ョョョョョョョョョョョIllLI国国11にILI肥1叫L王王王11臣11叫曲王王王臣1王王王王王王王王王王1王王王王王1王臣王王ー■',
#   '13',
#   '(1) 14',
#   '15',
#   '13',
#   '46',
#   '93',
#   '110',
#   'S7',
#   '68',
#   '61',
#   '52',
#   '45'],
#  ['',
#   '30',
#   '37',
#   '26',
#   'lfi',
#   '23',
#   '15',
#   '11',
#   '6',
#   '0',
#   '(0)0',
#   '(0)0',
#   '781'],
#  ['000194',
#   '上野4丁目',
#   '2',
#   '1',
#   '0',
#   '2',
#   '1',
#   '2',
#   '0',
#   '3',
#   '2',
#   'I',
#   '(0)0',
#   ''],
#  ['', '6', '3', '0', '1', '4', '4', 'I', '(0)0', '0', '0', '(0)0', ''],
#  ['000195',
#   '上野ST目',
#   '7',
#   '6',
#   '3',
#   '5',
#   '21',
#   '(2)70',
#   '74',
#   '66',
#   '55',
#   '59',
#   '16',
#   ''],
#  ['', '30', '33', '25', '29', '20', '10', '15', '1', '0', '0', '(0)0', ''],
#  ['000196',
#   '上野6丁鳳',
#   '2',
#   '4',
#   '(0)2',
#   '7',
#   '7',
#   '14',
#   '14',
#   '9',
#   '15',
#   '16',
#   '4',
#   ''],
#  ['', '17', '13', '15', '15', '11', '14', '4', '4', '0', '0', '(a)0', '211'],
#  ['区7り',
#   '政9証Ql野行0導1千00',
#   '37',
#   'S',
#   '35',
#   '(4) 47',
#   '74',
#   '92',
#   '121',
#   '102',
#   '113',
#   '112',
#   '128',
#   '107'],
#  ['',
#   '73',
#   'LD一',
#   '56',
#   '(1)47',
#   '34',
#   '(0)14',
#   '10',
#   '2',
#   '0',
#   '0',
#   '(0)0',
#   '1,299'],
#  ['徴00020「朔',
#   '',
#   '(3) 39',
#   '35',
#   '25',
#   '46',
#   '154',
#   '148',
#   '130',
#   '115',
#   '101',
#   '112',
#   '43',
#   '82'],
#  ['',
#   '46',
#   '48',
#   '53',
#   '51',
#   '44',
#   '2l',
#   '13',
#   '5',
#   'O',
#   '0',
#   '(0)0',
#   '1,370'],
#  ['000202',
#   '東上野2丁目',
#   '17',
#   '13',
#   '10',
#   '18',
#   '58',
#   '122',
#   '(24)65',
#   '79',
#   '68',
#   '66',
#   '61',
#   ''],
#  ['', '28', '30', '39', '29', '35', '24', '7', '2', '1', '0', '(0)0', ''],
#  ['000203',
#   '東上野3丁目',
#   '53',
#   '41',
#   '35',
#   '32',
#   '76',
#   '148',
#   '135',
#   '121',
#   '117',
#   '97',
#   '117',
#   ''],
#  ['',
#   '(4) 101',
#   '60',
#   '89',
#   '72',
#   '83',
#   '56',
#   '31',
#   '8',
#   '2',
#   '0',
#   '(0)0',
#   ''],
#  ['000204',
#   '東上野4丁目',
#   '30',
#   '26',
#   '28',
#   '35',
#   '61',
#   '140',
#   '131',
#   '102',
#   '100',
#   '105',
#   '109',
#   '(3) 76'],
#  ['',
#   '57',
#   '39',
#   '63',
#   '47',
#   '43',
#   '34',
#   '(0)8',
#   '4',
#   '0',
#   '(0)0',
#   '(0)0',
#   '1, 242'],
#  ['000205',
#   '東上野5丁目',
#   '94',
#   '64',
#   '65',
#   '55',
#   '78',
#   '60',
#   '189',
#   '207',
#   '171',
#   '205',
#   '(7)105',
#   '141'],
#  ['',
#   '107',
#   '(2) 84',
#   '98',
#   '85',
#   '69',
#   '44',
#   'l7',
#   '5',
#   '0',
#   '0',
#   '(0)0',
#   '2,110'],
#  ['拒妬野',
#   '政20雄1行00一し斗100東丁',
#   '74',
#   '90',
#   '66',
#   '68',
#   '108',
#   '210',
#   '170',
#   '185',
#   '180',
#   '173',
#   '155',
#   '(5) 123'],
#  ['',
#   '82',
#   '79',
#   '103',
#   '(0)40',
#   '66',
#   '55',
#   '22',
#   '7',
#   '1',
#   '(0)0',
#   '(0)0',
#   '2;103'],
#  ['000211',
#   '元浅草1丁目',
#   '71',
#   '59',
#   '73',
#   '56',
#   '75',
#   '250',
#   '199',
#   '199',
#   '202',
#   '218',
#   '(6)87',
#   '133'],
#  ['',
#   '(3) 90',
#   '86',
#   '87',
#   '76',
#   '48',
#   '41',
#   '15',
#   '(o)5',
#   '2',
#   '1',
#   '(0)0',
#   '2,175'],
#  ['000212',
#   '元浅草2丁胃',
#   '32',
#   '25',
#   '15',
#   '11',
#   '37',
#   '119',
#   '111',
#   '91',
#   '95',
#   '59',
#   '(3) 60',
#   '44'],
#  ['', '49', '31', '37', '36', '39', '18', '13', '0', 'I', '0', '(0)0', '923'],
#  ['000213',
#   '元浅草3丁目',
#   '一',
#   '一・',
#   '66',
#   '70',
#   '91',
#   '202',
#   '219',
#   '218',
#   '(4)84',
#   '211',
#   '186',
#   '147'],
#  ['',
#   '97',
#   '85',
#   '110',
#   '73',
#   '64',
#   '29',
#   '10',
#   '3',
#   '1',
#   'I',
#   '(0)0',
#   '1,135 (71)'],
#  ['000214',
#   '元浅草4 T目',
#   '(1) 59',
#   '67',
#   '68',
#   '58',
#   '65',
#   '142',
#   '141',
#   '161',
#   '86',
#   '155',
#   '163',
#   '(8)98'],
#  ['',
#   '88',
#   '65',
#   '81',
#   '74',
#   '43',
#   '43',
#   '(0)15',
#   '5',
#   '1',
#   '0',
#   '0',
#   '(58) 926'],
#  ['正芭n乙IL',
#   '」1いnl一】丁一n211nU一一干一nョメ国国」国』国国』国』国国」国」国』国国国』国国』国国国1』国国国国』国」国』国国国』国国国国』国国国国国国国国国国国国国1山国国国国コ国',
#   '61',
#   '59',
#   '62',
#   '49',
#   '66',
#   '(3) 156',
#   '167',
#   '(2) 148',
#   '163',
#   '198',
#   '170',
#   '147'],
#  ['',
#   '80',
#   '81',
#   '89',
#   '81',
#   '63',
#   '44',
#   '23',
#   '10',
#   '1',
#   'O',
#   '(0)0',
#   '1,918'],
#  ['000222',
#   '寿2T目',
#   '52',
#   '34',
#   '21',
#   '17',
#   '24',
#   '82',
#   '97',
#   '(3) 75',
#   '101',
#   '72',
#   '78',
#   '46'],
#  ['', '48', '35', '39', '44', '38', '17', '12', '2', '0', '0', '(0)0', '934'],
#  ['000223',
#   '寿3丁目',
#   '(2) 88',
#   '(1) 91',
#   '78',
#   '(3) 76',
#   '123',
#   '(20)130',
#   '223',
#   '(8)225',
#   '229',
#   '221',
#   '207',
#   '199'],
#  ['',
#   '128',
#   '101',
#   '142',
#   '88',
#   '66',
#   '51',
#   '(0)19',
#   '4',
#   '0',
#   '0',
#   '(0)0',
#   '2,612'],
#  ['000224',
#   '寿4丁目',
#   '35',
#   '20',
#   '27',
#   '38',
#   '41',
#   '104',
#   '(3) 74',
#   '83',
#   '69',
#   '93',
#   '(2)76',
#   '(3) 50'],
#  ['',
#   '53',
#   '52',
#   '83',
#   '(1) 49',
#   '33',
#   '22',
#   '17',
#   '7',
#   '0',
#   'l',
#   '(a)0',
#   '1, 027'],
#  ['000231',
#   '駒形1丁目',
#   '71',
#   '40',
#   '(2) 33',
#   '34',
#   '72',
#   '162',
#   '167',
#   '156',
#   '157',
#   '151',
#   '(7)67',
#   'g4'],
#  ['',
#   '(1) 73',
#   '46',
#   '53',
#   '33',
#   '52',
#   '33',
#   '6',
#   '1',
#   '1',
#   '0',
#   '(0)0',
#   '1,563'],
#  ['区2ジ',
#   '政23引誕02形行00酬―子00駒目',
#   '22',
#   '17',
#   '24',
#   '26',
#   '27',
#   '48',
#   '84',
#   '63',
#   '63',
#   '80',
#   '79',
#   '56'],
#  ['', '5S', '47', '47', '26', '23', '10', '10', '6', '0', '0', '(0)0', '816'],
#  ['000241',
#   '北上野1丁目',
#   '51',
#   '24',
#   '26',
#   '18',
#   '72',
#   '130',
#   '138',
#   '113',
#   '101',
#   '94',
#   '112',
#   ''],
#  ['', '37', '42', '40', '21', '19', '12', '7', '3', '1', '0', '(0)0', ''],
#  ['000242',
#   '北上野2丁目',
#   '94',
#   '80',
#   '82',
#   '93',
#   '206',
#   '373',
#   '301',
#   '295',
#   '257',
#   '263',
#   '(7)134',
#   ''],
#  ['',
#   '6',
#   '134',
#   '138',
#   '104',
#   '71',
#   '51',
#   '17',
#   '6',
#   '0',
#   '0',
#   '(0)0',
#   '3, 186'],
#  ['000251',
#   '下谷1丁目',
#   '47',
#   '55',
#   '78',
#   '87',
#   '98',
#   '181',
#   '168',
#   '168',
#   '64',
#   '(8) 210',
#   '(5) 86',
#   '140'],
#  ['',
#   '97',
#   '81',
#   '(1) 113',
#   '87',
#   '(1) 59',
#   '41',
#   '12',
#   '12',
#   '1',
#   '0',
#   '(0)0',
#   '2,058'],
#  ['000252',
#   '下谷2丁目',
#   '66',
#   '(5) 100',
#   '101',
#   '105',
#   '144',
#   '255',
#   '186',
#   '202',
#   '209',
#   '255',
#   '150',
#   '235'],
#  ['',
#   '(6) 158',
#   '171',
#   '184',
#   '(1) 173',
#   '105',
#   '82',
#   '46',
#   '10',
#   '0',
#   '0',
#   '(0)O',
#   '3,087'],
#  ['記是n乙gJ',
#   '一丁nUノ41Jァ1一n一1、コJ4一n】1ILLI十',
#   '60',
#   '61',
#   '56',
#   '59',
#   '138',
#   '177',
#   '190',
#   '165',
#   '170',
#   '208',
#   '217',
#   '131'],
#  ['',
#   '10?',
#   '84',
#   '(2) 119',
#   '86',
#   '78',
#   '56',
#   '20',
#   '6',
#   '1',
#   '0',
#   '(0)0',
#   '2,189']]
